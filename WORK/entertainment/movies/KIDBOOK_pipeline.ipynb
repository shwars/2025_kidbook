# %% [markdown]
# ### Изменяемые параметры

# %%
begin_term = 'Q11424' # "Центр" графа - стартовая точка
rel_limiter = 50 # Максимальное число связей в графе
AUTH_KEY = ""  # Ключ авторизации Гигачат

# %% [markdown]
# ### Отправка SPARQL-запроса

# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
from pprint import pprint

endpoint_url = "https://query.wikidata.org/sparql"

# Формирует запрос
def form_begin_query(term, num_of_relations):
  begin_query = f"""
  #Subproperties and parts of film
  #defaultView:Graph
  SELECT DISTINCT ?searched ?searchedLabel ?searchedDesc ?relation ?property ?propertyLabel ?propertyDesc WHERE {{
    
    {{
      BIND(wd:{term} as ?searched)
      # ?searched ?relation ?property.
      FILTER(?relation in (wdt:P2579, wdt:P1552, wdt:P527, wdt:P1963))
      
      # ?searched rdfs:label ?searchedLabel.
      # ?searched schema:description ?searchedDesc.
      
      # ?property rdfs:label ?propertyLabel.
      # ?property schema:description ?propertyDesc.
    }}
    UNION
    {{
      wd:{term} ?relation1 ?searched.
      FILTER(?relation1 in (wdt:P2579, wdt:P1552, wdt:P527, wdt:P1963))
      
      # ?searched ?relation ?property.
      FILTER(?relation in (wdt:P2579, wdt:P1552, wdt:P527, wdt:P1963, wdt:P1659))
      
      # ?searched rdfs:label ?searchedLabel.
      # ?searched schema:description ?searchedDesc.
      
      # ?property rdfs:label ?propertyLabel.
      # ?property schema:description ?propertyDesc.
    }}
    
    FILTER((lang(?searchedLabel) = 'ru') && regex(STR(?searchedLabel), "^[а-я]") && !regex(STR(?searchedLabel), "код") && !regex(STR(?searchedLabel), "номер")).  
    FILTER((lang(?searchedDesc) = 'ru')).
    FILTER((lang(?propertyLabel) = 'ru') && regex(STR(?propertyLabel), "^[а-я]") && !regex(STR(?propertyLabel), "код") && !regex(STR(?propertyLabel), "номер")).  
    FILTER((lang(?propertyDesc) = 'ru')).
  }} LIMIT {num_of_relations}
  """
  return begin_query

# Отправляет SPARQL-запрос и принимает ответ
def SPARQL_query(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
SPARQL_result = SPARQL_query(endpoint_url, form_begin_query(begin_term, rel_limiter))

for result in SPARQL_result["results"]["bindings"]:
    pprint(result)
# Out:
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P58'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор(ы) сценария фильма',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'сценарист', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P57'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной '
#                            'игры и др. произведений искусства',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'режиссёр', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P136'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'жанр произведения или жанр, в котором работает '
#                            'автор',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'жанр', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P170'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель творческого произведения и т. п. (для '
#                            'случаев, когда нет более точного свойства)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'создатель', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P57'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной '
#                            'игры и др. произведений искусства',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'режиссёр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P161'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'актёры данного произведения; используйте '
#                            'квалификаторы для разделения главных и '
#                            'второстепенных ролей',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'в ролях', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P166'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'награды, полученные персоной, организацией или '
#                            'произведением',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'полученные награды',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P676'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор слов песен',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'автор слов', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P10806'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'лицо или организация, ответственная за аранжировку '
#                            'музыкального произведения для оркестра',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'оркестровщик',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28793'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'научная дисциплина, тесно связанная с критической '
#                            'теорией, которая направлена на изучение сущности '
#                            'кино и обеспечивает концептуальную основу для '
#                            'понимания в отношениях фильма и реальности, других '
#                            'искусств, зрителя, общества',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'теория кино', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P2579'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri',
#               'value': 'http://www.wikidata.org/entity/Q1660187'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'наука о теории, истории и социологии '
#                            'кинематографа, киноискусства',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'киноведение', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P2579'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P170'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель творческого произведения и т. п. (для '
#                            'случаев, когда нет более точного свойства)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'создатель', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P87'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор текста к опере, оратории, оперетте, мюзиклу '
#                            'или кантате',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'автор либретто',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P50'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'автор', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P50'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'автор', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P57'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной '
#                            'игры и др. произведений искусства',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'режиссёр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P135'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'литературное, художественное или философское '
#                            'направление, связанное с этой персоной или '
#                            'произведением',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'школа (движение)',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P136'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'жанр произведения или жанр, в котором работает '
#                            'автор',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'жанр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P144'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'то (произведение), что послужило идеей, базой, '
#                            'основой',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'создано на основе',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P364'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'язык, на котором первоначально был создан фильм '
#                            'или произведение (для письменных произведений '
#                            'используйте P407 «язык произведения или названия»)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'язык оригинала фильма или телешоу',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P179'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'ряд или последовательность, в которой состоит '
#                            'данный элемент',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'является частью цикла',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P175'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'актёр, музыкант или группа, имеющие отношение к '
#                            'данной музыкальной работе',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'исполнитель', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P161'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'актёры данного произведения; используйте '
#                            'квалификаторы для разделения главных и '
#                            'второстепенных ролей',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'в ролях', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P272'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'компания, производящая фильм, музыку или '
#                            'театральную постановку',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'производящая компания',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P344'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'кинематографическая профессия, ответственный за '
#                            'съёмку, освещение и фильтрацию',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'кинооператор',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1346'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'победитель соревнования',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'победитель', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P166'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'награды, полученные персоной, организацией или '
#                            'произведением',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'полученные награды',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P676'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор слов песен',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'автор слов', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1686'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'произведение, за которое присуждена данная награда',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'за работу', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P166'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'награды, полученные персоной, организацией или '
#                            'произведением',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'полученные награды',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P921'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'главная тема работы, произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'основная тема',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P136'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'жанр произведения или жанр, в котором работает '
#                            'автор',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'жанр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P170'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель творческого произведения и т. п. (для '
#                            'случаев, когда нет более точного свойства)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'создатель', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P676'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор слов песен',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'автор слов', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P462'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'цвет элемента',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'цвет', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P750'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'распространитель работы',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'распространяется',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P86'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'автор музыкального произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'композитор', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P676'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор слов песен',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'автор слов', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P725'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'исполнитель устной роли в творческой работе, такой '
#                            'как анимация, видеоигра, радиопостановка или '
#                            'дубляж [используйте "играет роль персонажа" (P453) '
#                            'в качестве квалификатора] [используйте «в ролях» '
#                            '(P161) для живого исполнения]',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'актёр озвучивания',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P161'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'актёры данного произведения; используйте '
#                            'квалификаторы для разделения главных и '
#                            'второстепенных ролей',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'в ролях', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7937'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'структура творческой работы, тип музыкального '
#                            'релиза',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'форма творческой работы',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P136'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'жанр произведения или жанр, в котором работает '
#                            'автор',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'жанр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7984'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'свойство описывает в каком виде изображён объект, '
#                            'например "портрет в три четверти" или "панорама"',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'формат изображения',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P136'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'жанр произведения или жанр, в котором работает '
#                            'автор',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'жанр', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P921'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'главная тема работы, произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'основная тема',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P495'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'страна происхождения творческого произведения или '
#                            'другого продукта',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'страна происхождения',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P3274'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'третье лицо, через которое был получен доступ к '
#                            'данному контенту',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'хостинг', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P750'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'распространитель работы',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'распространяется',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P437'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'у творческой работы: её метод распространения или '
#                            'носитель',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'распространение произведения',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P750'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'распространитель работы',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'распространяется',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P915'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'место, где снимался фильм. Для места действия '
#                            'используйте P840',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'место съёмок',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P577'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'дата, когда произведение было выпущено в свет',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'дата публикации',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P50'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'создатель произведения',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'автор', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P676'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'автор слов песен',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'автор слов', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P840'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'сюжет данного произведения происходит в данном '
#                            'местоположении',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'место действия',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P495'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'страна происхождения творческого произведения или '
#                            'другого продукта',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'страна происхождения',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P915'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'место, где снимался фильм. Для места действия '
#                            'используйте P840',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'место съёмок',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1040'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'человек, который работает с плёнкой (записью), '
#                            'выбирая нужные кадры/последовательности',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'монтажёр', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1411'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'номинация на премию, полученная человеком, '
#                            'организацией или творческим произведением (для '
#                            'полученных наград см. Property:P166)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'номинирован(а) на',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P166'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'награды, полученные персоной, организацией или '
#                            'произведением',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'полученные награды',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P11108'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'субъект, принимающий активное участие в '
#                            'документальном фильме или другом записанном '
#                            'произведении',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'записанный участник',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P161'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'актёры данного произведения; используйте '
#                            'квалификаторы для разделения главных и '
#                            'второстепенных ролей',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'в ролях', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1411'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'номинация на премию, полученная человеком, '
#                            'организацией или творческим произведением (для '
#                            'полученных наград см. Property:P166)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'номинирован(а) на',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P180'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'изображённая персона, место, объект или событие',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'изображённый объект',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P144'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'то (произведение), что послужило идеей, базой, '
#                            'основой',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'создано на основе',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P1476'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'название произведения (книги, фильма, газетной '
#                            'статьи, произведения исполнительского искусства, '
#                            'веб-сайта)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal', 'value': 'название', 'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1963'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11424'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'совокупность движущихся изображений, связанных '
#                            'единым сюжетом',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'фильм', 'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P180'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'изображённая персона, место, объект или событие',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'изображённый объект',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P915'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'место, где снимался фильм. Для места действия '
#                            'используйте P840',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal',
#                    'value': 'место съёмок',
#                    'xml:lang': 'ru'}}
# {'property': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P453'},
#  'propertyDesc': {'type': 'literal',
#                   'value': 'квалификатор для свойств «в ролях» (P161) и «актёр '
#                            'озвучивания» (P725)',
#                   'xml:lang': 'ru'},
#  'propertyLabel': {'type': 'literal',
#                    'value': 'играет роль персонажа',
#                    'xml:lang': 'ru'},
#  'relation': {'type': 'uri',
#               'value': 'http://www.wikidata.org/prop/direct/P1659'},
#  'searched': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P161'},
#  'searchedDesc': {'type': 'literal',
#                   'value': 'актёры данного произведения; используйте '
#                            'квалификаторы для разделения главных и '
#                            'второстепенных ролей',
#                   'xml:lang': 'ru'},
#  'searchedLabel': {'type': 'literal', 'value': 'в ролях', 'xml:lang': 'ru'}}

# %% [markdown]
# ### Фильтрация результата SPARQL-запроса

# %%
# Чистит ненужную информацию о типах из результата запроса для одной строки
def filter_JSON_line(line):
    filtered_line = {
        'searched': line.get('searched').get('value').split("/")[-1],
        'searchedLabel': line.get('searchedLabel').get('value'),
        'searchedDesc': line.get('searchedDesc').get('value'),

        'relation': line.get('relation').get('value').split("/")[-1],

        'property': line.get('property').get('value').split("/")[-1],
        'propertyLabel': line.get('propertyLabel').get('value'),
        'propertyDesc': line.get('propertyDesc').get('value')
    }
    
    return filtered_line

# Чистит весь ответ
def filter_SPARQL_result(input_json):
    return [filter_JSON_line(line) for line in input_json["results"]["bindings"]]

# %%
filtered_list = filter_SPARQL_result(SPARQL_result)
pprint(filtered_list)
# Out:
# [{'property': 'P58',
#   'propertyDesc': 'автор(ы) сценария фильма',
#   'propertyLabel': 'сценарист',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P57',
#   'propertyDesc': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной игры и др. '
#                   'произведений искусства',
#   'propertyLabel': 'режиссёр',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P136',
#   'propertyDesc': 'жанр произведения или жанр, в котором работает автор',
#   'propertyLabel': 'жанр',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P170',
#   'propertyDesc': 'создатель творческого произведения и т. п. (для случаев, '
#                   'когда нет более точного свойства)',
#   'propertyLabel': 'создатель',
#   'relation': 'P1659',
#   'searched': 'P57',
#   'searchedDesc': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной игры и др. '
#                   'произведений искусства',
#   'searchedLabel': 'режиссёр'},
#  {'property': 'P86',
#   'propertyDesc': 'автор музыкального произведения',
#   'propertyLabel': 'композитор',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P161',
#   'propertyDesc': 'актёры данного произведения; используйте квалификаторы для '
#                   'разделения главных и второстепенных ролей',
#   'propertyLabel': 'в ролях',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P166',
#   'propertyDesc': 'награды, полученные персоной, организацией или '
#                   'произведением',
#   'propertyLabel': 'полученные награды',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P676',
#   'propertyDesc': 'автор слов песен',
#   'propertyLabel': 'автор слов',
#   'relation': 'P1659',
#   'searched': 'P86',
#   'searchedDesc': 'автор музыкального произведения',
#   'searchedLabel': 'композитор'},
#  {'property': 'P10806',
#   'propertyDesc': 'лицо или организация, ответственная за аранжировку '
#                   'музыкального произведения для оркестра',
#   'propertyLabel': 'оркестровщик',
#   'relation': 'P1659',
#   'searched': 'P86',
#   'searchedDesc': 'автор музыкального произведения',
#   'searchedLabel': 'композитор'},
#  {'property': 'Q28793',
#   'propertyDesc': 'научная дисциплина, тесно связанная с критической теорией, '
#                   'которая направлена на изучение сущности кино и обеспечивает '
#                   'концептуальную основу для понимания в отношениях фильма и '
#                   'реальности, других искусств, зрителя, общества',
#   'propertyLabel': 'теория кино',
#   'relation': 'P2579',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'Q1660187',
#   'propertyDesc': 'наука о теории, истории и социологии кинематографа, '
#                   'киноискусства',
#   'propertyLabel': 'киноведение',
#   'relation': 'P2579',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P170',
#   'propertyDesc': 'создатель творческого произведения и т. п. (для случаев, '
#                   'когда нет более точного свойства)',
#   'propertyLabel': 'создатель',
#   'relation': 'P1659',
#   'searched': 'P86',
#   'searchedDesc': 'автор музыкального произведения',
#   'searchedLabel': 'композитор'},
#  {'property': 'P87',
#   'propertyDesc': 'автор текста к опере, оратории, оперетте, мюзиклу или '
#                   'кантате',
#   'propertyLabel': 'автор либретто',
#   'relation': 'P1659',
#   'searched': 'P86',
#   'searchedDesc': 'автор музыкального произведения',
#   'searchedLabel': 'композитор'},
#  {'property': 'P50',
#   'propertyDesc': 'создатель произведения',
#   'propertyLabel': 'автор',
#   'relation': 'P1659',
#   'searched': 'P86',
#   'searchedDesc': 'автор музыкального произведения',
#   'searchedLabel': 'композитор'},
#  {'property': 'P50',
#   'propertyDesc': 'создатель произведения',
#   'propertyLabel': 'автор',
#   'relation': 'P1659',
#   'searched': 'P57',
#   'searchedDesc': 'режиссёр(ы) фильма, сериала, пьесы, компьютерной игры и др. '
#                   'произведений искусства',
#   'searchedLabel': 'режиссёр'},
#  {'property': 'P135',
#   'propertyDesc': 'литературное, художественное или философское направление, '
#                   'связанное с этой персоной или произведением',
#   'propertyLabel': 'школа (движение)',
#   'relation': 'P1659',
#   'searched': 'P136',
#   'searchedDesc': 'жанр произведения или жанр, в котором работает автор',
#   'searchedLabel': 'жанр'},
#  {'property': 'P144',
#   'propertyDesc': 'то (произведение), что послужило идеей, базой, основой',
#   'propertyLabel': 'создано на основе',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P364',
#   'propertyDesc': 'язык, на котором первоначально был создан фильм или '
#                   'произведение (для письменных произведений используйте P407 '
#                   '«язык произведения или названия»)',
#   'propertyLabel': 'язык оригинала фильма или телешоу',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P179',
#   'propertyDesc': 'ряд или последовательность, в которой состоит данный '
#                   'элемент',
#   'propertyLabel': 'является частью цикла',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P175',
#   'propertyDesc': 'актёр, музыкант или группа, имеющие отношение к данной '
#                   'музыкальной работе',
#   'propertyLabel': 'исполнитель',
#   'relation': 'P1659',
#   'searched': 'P161',
#   'searchedDesc': 'актёры данного произведения; используйте квалификаторы для '
#                   'разделения главных и второстепенных ролей',
#   'searchedLabel': 'в ролях'},
#  {'property': 'P272',
#   'propertyDesc': 'компания, производящая фильм, музыку или театральную '
#                   'постановку',
#   'propertyLabel': 'производящая компания',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P344',
#   'propertyDesc': 'кинематографическая профессия, ответственный за съёмку, '
#                   'освещение и фильтрацию',
#   'propertyLabel': 'кинооператор',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P1346',
#   'propertyDesc': 'победитель соревнования',
#   'propertyLabel': 'победитель',
#   'relation': 'P1659',
#   'searched': 'P166',
#   'searchedDesc': 'награды, полученные персоной, организацией или '
#                   'произведением',
#   'searchedLabel': 'полученные награды'},
#  {'property': 'P676',
#   'propertyDesc': 'автор слов песен',
#   'propertyLabel': 'автор слов',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P1686',
#   'propertyDesc': 'произведение, за которое присуждена данная награда',
#   'propertyLabel': 'за работу',
#   'relation': 'P1659',
#   'searched': 'P166',
#   'searchedDesc': 'награды, полученные персоной, организацией или '
#                   'произведением',
#   'searchedLabel': 'полученные награды'},
#  {'property': 'P921',
#   'propertyDesc': 'главная тема работы, произведения',
#   'propertyLabel': 'основная тема',
#   'relation': 'P1659',
#   'searched': 'P136',
#   'searchedDesc': 'жанр произведения или жанр, в котором работает автор',
#   'searchedLabel': 'жанр'},
#  {'property': 'P170',
#   'propertyDesc': 'создатель творческого произведения и т. п. (для случаев, '
#                   'когда нет более точного свойства)',
#   'propertyLabel': 'создатель',
#   'relation': 'P1659',
#   'searched': 'P676',
#   'searchedDesc': 'автор слов песен',
#   'searchedLabel': 'автор слов'},
#  {'property': 'P462',
#   'propertyDesc': 'цвет элемента',
#   'propertyLabel': 'цвет',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P750',
#   'propertyDesc': 'распространитель работы',
#   'propertyLabel': 'распространяется',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P86',
#   'propertyDesc': 'автор музыкального произведения',
#   'propertyLabel': 'композитор',
#   'relation': 'P1659',
#   'searched': 'P676',
#   'searchedDesc': 'автор слов песен',
#   'searchedLabel': 'автор слов'},
#  {'property': 'P725',
#   'propertyDesc': 'исполнитель устной роли в творческой работе, такой как '
#                   'анимация, видеоигра, радиопостановка или дубляж '
#                   '[используйте "играет роль персонажа" (P453) в качестве '
#                   'квалификатора] [используйте «в ролях» (P161) для живого '
#                   'исполнения]',
#   'propertyLabel': 'актёр озвучивания',
#   'relation': 'P1659',
#   'searched': 'P161',
#   'searchedDesc': 'актёры данного произведения; используйте квалификаторы для '
#                   'разделения главных и второстепенных ролей',
#   'searchedLabel': 'в ролях'},
#  {'property': 'P7937',
#   'propertyDesc': 'структура творческой работы, тип музыкального релиза',
#   'propertyLabel': 'форма творческой работы',
#   'relation': 'P1659',
#   'searched': 'P136',
#   'searchedDesc': 'жанр произведения или жанр, в котором работает автор',
#   'searchedLabel': 'жанр'},
#  {'property': 'P7984',
#   'propertyDesc': 'свойство описывает в каком виде изображён объект, например '
#                   '"портрет в три четверти" или "панорама"',
#   'propertyLabel': 'формат изображения',
#   'relation': 'P1659',
#   'searched': 'P136',
#   'searchedDesc': 'жанр произведения или жанр, в котором работает автор',
#   'searchedLabel': 'жанр'},
#  {'property': 'P921',
#   'propertyDesc': 'главная тема работы, произведения',
#   'propertyLabel': 'основная тема',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P495',
#   'propertyDesc': 'страна происхождения творческого произведения или другого '
#                   'продукта',
#   'propertyLabel': 'страна происхождения',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P3274',
#   'propertyDesc': 'третье лицо, через которое был получен доступ к данному '
#                   'контенту',
#   'propertyLabel': 'хостинг',
#   'relation': 'P1659',
#   'searched': 'P750',
#   'searchedDesc': 'распространитель работы',
#   'searchedLabel': 'распространяется'},
#  {'property': 'P437',
#   'propertyDesc': 'у творческой работы: её метод распространения или носитель',
#   'propertyLabel': 'распространение произведения',
#   'relation': 'P1659',
#   'searched': 'P750',
#   'searchedDesc': 'распространитель работы',
#   'searchedLabel': 'распространяется'},
#  {'property': 'P915',
#   'propertyDesc': 'место, где снимался фильм. Для места действия используйте '
#                   'P840',
#   'propertyLabel': 'место съёмок',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P577',
#   'propertyDesc': 'дата, когда произведение было выпущено в свет',
#   'propertyLabel': 'дата публикации',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P50',
#   'propertyDesc': 'создатель произведения',
#   'propertyLabel': 'автор',
#   'relation': 'P1659',
#   'searched': 'P676',
#   'searchedDesc': 'автор слов песен',
#   'searchedLabel': 'автор слов'},
#  {'property': 'P840',
#   'propertyDesc': 'сюжет данного произведения происходит в данном '
#                   'местоположении',
#   'propertyLabel': 'место действия',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P495',
#   'propertyDesc': 'страна происхождения творческого произведения или другого '
#                   'продукта',
#   'propertyLabel': 'страна происхождения',
#   'relation': 'P1659',
#   'searched': 'P915',
#   'searchedDesc': 'место, где снимался фильм. Для места действия используйте '
#                   'P840',
#   'searchedLabel': 'место съёмок'},
#  {'property': 'P1040',
#   'propertyDesc': 'человек, который работает с плёнкой (записью), выбирая '
#                   'нужные кадры/последовательности',
#   'propertyLabel': 'монтажёр',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P1411',
#   'propertyDesc': 'номинация на премию, полученная человеком, организацией или '
#                   'творческим произведением (для полученных наград см. '
#                   'Property:P166)',
#   'propertyLabel': 'номинирован(а) на',
#   'relation': 'P1659',
#   'searched': 'P166',
#   'searchedDesc': 'награды, полученные персоной, организацией или '
#                   'произведением',
#   'searchedLabel': 'полученные награды'},
#  {'property': 'P11108',
#   'propertyDesc': 'субъект, принимающий активное участие в документальном '
#                   'фильме или другом записанном произведении',
#   'propertyLabel': 'записанный участник',
#   'relation': 'P1659',
#   'searched': 'P161',
#   'searchedDesc': 'актёры данного произведения; используйте квалификаторы для '
#                   'разделения главных и второстепенных ролей',
#   'searchedLabel': 'в ролях'},
#  {'property': 'P1411',
#   'propertyDesc': 'номинация на премию, полученная человеком, организацией или '
#                   'творческим произведением (для полученных наград см. '
#                   'Property:P166)',
#   'propertyLabel': 'номинирован(а) на',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P180',
#   'propertyDesc': 'изображённая персона, место, объект или событие',
#   'propertyLabel': 'изображённый объект',
#   'relation': 'P1659',
#   'searched': 'P144',
#   'searchedDesc': 'то (произведение), что послужило идеей, базой, основой',
#   'searchedLabel': 'создано на основе'},
#  {'property': 'P1476',
#   'propertyDesc': 'название произведения (книги, фильма, газетной статьи, '
#                   'произведения исполнительского искусства, веб-сайта)',
#   'propertyLabel': 'название',
#   'relation': 'P1963',
#   'searched': 'Q11424',
#   'searchedDesc': 'совокупность движущихся изображений, связанных единым '
#                   'сюжетом',
#   'searchedLabel': 'фильм'},
#  {'property': 'P180',
#   'propertyDesc': 'изображённая персона, место, объект или событие',
#   'propertyLabel': 'изображённый объект',
#   'relation': 'P1659',
#   'searched': 'P915',
#   'searchedDesc': 'место, где снимался фильм. Для места действия используйте '
#                   'P840',
#   'searchedLabel': 'место съёмок'},
#  {'property': 'P453',
#   'propertyDesc': 'квалификатор для свойств «в ролях» (P161) и «актёр '
#                   'озвучивания» (P725)',
#   'propertyLabel': 'играет роль персонажа',
#   'relation': 'P1659',
#   'searched': 'P161',
#   'searchedDesc': 'актёры данного произведения; используйте квалификаторы для '
#                   'разделения главных и второстепенных ролей',
#   'searchedLabel': 'в ролях'}]

# %%
len(filtered_list)
# Out:
# 50

# %% [markdown]
# ### Работа с API LLM

# %%
import requests
import json
import time
from datetime import datetime

# Авторизационные данные
SCOPE = "GIGACHAT_API_PERS"  # Для физических лиц

# URL для получения токена и API
TOKEN_URL = "https://ngw.devices.sberbank.ru:9443/api/v2/oauth"
API_URL = "https://gigachat.devices.sberbank.ru/api/v1/chat/completions"

# Класс для управления токеном
class GigaChatClient:
    def __init__(self, auth_key, scope):
        self.auth_key = auth_key
        self.scope = scope
        self.access_token = None
        self.expires_at = 0  # Время истечения токена (в секундах с эпохи)
    
    # Проверка, истек ли токен
    def is_token_valid(self):
        current_time = int(time.time())
        # Добавляем буфер в 60 секунд, чтобы обновлять токен заранее
        return self.access_token is not None and current_time < (self.expires_at - 60)


    def get_access_token(self):
        if self.is_token_valid():
            return self.access_token

        headers = {
            "Content-Type": "application/x-www-form-urlencoded",
            "Accept": "application/json",
            "Authorization": f"Basic {self.auth_key}",
            "RqUID": "6f0b1291-c7f3-43c6-bb2e-9f3efb2dc98e"
        }
        payload = {
            "scope": self.scope
        }

        response = requests.post(TOKEN_URL, headers=headers, data=payload, verify=True)
        if response.status_code == 200:
            token_data = response.json()
            self.access_token = token_data["access_token"]
            self.expires_at = token_data["expires_at"] // 1000  # Преобразуем миллисекунды в секунды
            #print(f"Токен обновлен, действителен до: {datetime.fromtimestamp(self.expires_at)}")
            return self.access_token
        else:
            raise Exception(f"Ошибка получения токена: {response.status_code}, {response.text}")

    # Отправка запроса к GigaChat
    def send_request(self, message, model="GigaChat", temperature=1.0, max_tokens=512):
        access_token = self.get_access_token()

        headers = {
            "Content-Type": "application/json",
            "Accept": "application/json",
            "Authorization": f"Bearer {access_token}"
        }
        payload = {
            "model": model,
            "messages": [{"role": "user", "content": message}],
            "temperature": temperature,
            "max_tokens": max_tokens,
            "function_call": "auto"
        }

        response = requests.post(API_URL, headers=headers, data=json.dumps(payload), verify=True)
        if response.status_code == 200:
            return response.json()["choices"][0]["message"]["content"]
        else:
            raise Exception(f"Ошибка запроса к GigaChat: {response.status_code}, {response.text}")

# %%
client = GigaChatClient(AUTH_KEY, SCOPE)

# %% [markdown]
# #### Неиспользованный функионал по преобразованию понятий (Гигачат не смог, pymorphy 2 - перебор)

# %%
# Формирует запрос для изменения понятий
def form_label_message(label, desc):
    message = f"""Если "{label}" является словосочетанием в именительном падеже, верни его назад без изменений.
    Верни словосочетание в именительном падеже по определению: "{desc}".
    В ответе должно быть только словосочетание.
    """
    return message

# Формирует список новых названий для понятий из Wikidata
def get_changed_names(json_list):

    result_dict = {}

    for json_str in json_list:
        
        id = json_str.get('property')

        if id in result_dict:
            continue

        name = json_str.get('propertyLabel')
        desc = json_str.get('propertyDesc')
        
        result_dict[id] = client.send_request(form_label_message(name, desc), temperature=0.0)
    return result_dict

# %% [markdown]
# ### Формирование сообщений для LLM

# %%
# Формирует заголовок
def form_title_message(main_term, main_term_desc):
    message = f"""
    Сформируй для десятилетнего ребёнка короткий заголовок понятия "{main_term}" со смыслом "{main_term_desc}". 
    Никак его не выделяй заголовок.
    """
    return message

# Формирует описание понятия
def form_desc_message(main_term, main_term_desc):
    message = f"""
    Сформируй десятилетнего ребёнка абзац текста - подробное объяснение для  для понятия "{main_term}" со смыслом "{main_term_desc}" . 
    Текст не должен явно упоминать никаких других понятий, связанных с "{main_term}".
    """
    return message

# Формирует описание для связи понятий
def form_part_message(main_term, main_term_desc, related_term, related_term_desc):
    message = f"""
    Объясни для десятилетнего ребёнка про связь понятий "{main_term}" ({main_term_desc}) и "{related_term}" ({related_term_desc}) .
    Текст не должен явно упоминать никаких других понятий, связанных с {main_term} или {related_term}.
    Текст должен быть коротким. Рассказывай в первую очередь про {related_term}, не пиши текст близко к {main_term_desc}.
    """
    return message

# %% [markdown]
# ### Автоматическое формирование страниц на основе графа из SPARQL

# %%
# Собирает все связи текущего элемента в графе
def get_all_relatives(json_list, id):
    lines = []
    for json_line in json_list:
        if json_line.get('searched') == id:
            lines.append(json_line)
    return lines

# Собирает информацию для "центрального" элемента графа - точки старта
def select_begin_term_info(json_list, term):
    for json_line in json_list:
        if json_line.get('searched') == term:
            return {'searched': json_line.get('searched'), 'searchedLabel': json_line.get('searchedLabel'), 'searchedDesc': json_line.get('searchedDesc')}

# %%
import os

FOLDER = './pages/'
os.makedirs(FOLDER, exist_ok=True)

def make_filename(namestring):
    return namestring.replace(" ", "_")

# Создаёт страницу
def form_page(cur_info, rel_info):
    filename = make_filename(cur_info.get('searchedLabel')) + '.md'
    f = open(FOLDER + filename, 'w')
    f.write('# ' + client.send_request(form_title_message(cur_info.get('searchedLabel'), cur_info.get('searchedDesc'))) + '\n')
    f.write('### ' + client.send_request(form_desc_message(cur_info.get('searchedLabel'), cur_info.get('searchedDesc'))))
    for line in rel_info:
        friend_filename = line.get('propertyLabel').replace(" ", "_")
        f.write('\n## [' + client.send_request(form_title_message(line.get('propertyLabel'), line.get('propertyDesc'))) + f"](./{friend_filename}.md)\n")
        f.write(client.send_request(form_part_message(line.get('searchedLabel'), line.get('searchedDesc'), line.get('propertyLabel'), line.get('propertyDesc'))))
    f.close()

# Рекурсивный обход графа с вызыванием создания страниц
def form_pages_inner(json_list, rel_info, id_set):
    for json_line in rel_info:
        new_cur = {'searched': json_line.get('property'), 'searchedLabel': json_line.get('propertyLabel'), 'searchedDesc': json_line.get('propertyDesc')}
        new_term = new_cur.get('searched')
        if new_term in id_set:
            continue
        new_rel = get_all_relatives(json_list, new_term)
        form_page(new_cur, new_rel)
        id_set.add(new_term)
        form_pages_inner(json_list, new_rel, id_set)

# Общая функция для создания всех страниц
def form_pages(json_list):
    created_pages_id = set()
    cur_info = select_begin_term_info(json_list, begin_term)
    rel_info = get_all_relatives(json_list, begin_term)
    form_page(cur_info, rel_info)
    created_pages_id.add(begin_term)
    form_pages_inner(json_list, rel_info, created_pages_id)

# %%
form_pages(filtered_list)

# %% [markdown]
# ## Автоматическое формирование concepts.json

# %%
# Сбор всех понятий
def gather_all_terms(json_list):
    term_dict = dict()
    begin_term_info = select_begin_term_info(json_list, begin_term)
    term_dict[begin_term_info.get('searched')] = {"label": begin_term_info.get('searchedLabel'), "description": begin_term_info.get('searchedDesc'), 'filename': make_filename(begin_term_info.get('searchedLabel'))}
    for line in json_list:
        id = line.get('property')
        if id in term_dict:
            continue
        term_dict[id] = {"label": line.get('propertyLabel'), "description": line.get('propertyDesc')}
    return term_dict

# Создание concepts.json
def make_concepts(json_list):
    f = open('./concepts.json', 'w')
    f.write('[\n')
    
    term_dict = gather_all_terms(json_list)

    keys = list(term_dict.keys())
    
    key = keys[0]
    value = term_dict[key]
    new_dict = {"id": key, "label": value['label'], "description": value['description'], "filename": make_filename(value['label'])+'.md'}
    json.dump(new_dict, f, indent=4, ensure_ascii=False)

    for key in keys[1:]:
        f.write(',\n')
        value = term_dict[key]
        new_dict = {"id": key, "label": value['label'], "description": value['description'], "filename": make_filename(value['label'])+'.md'}
        json.dump(new_dict, f, indent=4, ensure_ascii=False)

    f.write('\n]')
    f.close()

# %%
make_concepts(filtered_list)

# %% [markdown]
# ## Автоматическое формирование графика для отчёта

# %% [markdown]
# #### Неиспользуемый функционал (Гитхаб не знает PlantUML)

# %%
def generate_plantuml(json_list, filename="report.md"):
    with open(filename, "w", encoding="utf-8") as f:
        f.write("### Отчёт\n")
        f.write("## Онтология\n")
        f.write('```plantuml\n')
        f.write("@startuml\n")
        f.write("left to right direction\n")
        
        entities = set()
        for line in json_list:
            entities.add(line['searchedLabel'])
            entities.add(line['propertyLabel'])
        
        for entity in entities:
            f.write(f'class "{entity}"\n')
        
        for line in json_list:
            source = line['searchedLabel']
            target = line['propertyLabel']
            relation = line['relation']
            f.write(f'"{source}" --> "{target}" : "{relation}"\n')
        
        f.write("@enduml\n")
        f.write('```')

# %% [markdown]
# #### Генерация mermaid-графика

# %%
def generate_mermaid(json_list, filename="report.md"):
    with open(filename, "w", encoding="utf-8") as f:
        f.write("# Отчёт\n")
        f.write("## Онтология\n")
        
        f.write('```mermaid\n')
        f.write("classDiagram\n")
        f.write("  direction LR\n")
        
        for line in json_list:
            source = make_filename(line['searchedLabel']).replace("(", "-").replace(")", "-")
            target = make_filename(line['propertyLabel']).replace("(", "-").replace(")", "-")
            relation = line['relation']
            f.write(f'  {source} --> {target} : "{relation}"\n')
        f.write('```')

# %%
generate_mermaid(filtered_list)
